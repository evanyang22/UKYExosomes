# %%
import os
import csv
import pandas as pd
import PySimpleGUI as sg

sg.theme('SandyBeach')
layout = [
    [sg.Text('How many normalization columns would you like to add?')],
    [sg.Text('Number of times', size =(15, 1)), sg.InputText()],
    [sg.Submit(), sg.Cancel()]
]
window = sg.Window('Simple data entry window', layout)
event, values = window.read()
window.close()


numTimes=int(values[0])
counter=0

while counter<numTimes:
    sg.theme('SandyBeach')
    layout = [
        [sg.Text('Please enter reference m/z and name for new column')],
        [sg.Text('Reference m/z', size =(15, 1)), sg.InputText()],
        [sg.Text('Column Name', size =(15, 1)), sg.InputText()],
        [sg.Submit(), sg.Cancel()]
    ]
    window = sg.Window('Simple data entry window', layout)
    event, values = window.read()
    window.close()

    refNum=float(values[0])
    newColumnHeader=values[1]


    print("Using reference m/z of " + str(refNum))
    print("New Column Name is "+ newColumnHeader)
    for filename in os.scandir():
        try:
            if filename.path.endswith(".csv"):
                df = pd.read_csv(filename.name)
                #extracts denominator using refNum and 13C==0 
                denominator=df.loc[(df['Ref m/z'] == refNum) & (df["13C"]==0)]["Corrected Intensity"].iloc[0]
                #dividing everything and adding to column
                addColumn=[]
                numerators= df["Corrected Intensity"]
                for num in numerators:
                    addColumn.append(num/denominator)
                df[newColumnHeader]=addColumn
                #overwrites to csv
                df.to_csv(filename.name, index=False)
            print("Done: "+ filename.name)
        except:
            print("Error: " +filename.name)
            pass
    
    counter+=1
# Out:
# Using reference m/z of 740.54645
# New Column Name is test1
# Done: .ipynb_checkpoints
# Error: ._nacorrected_asgngrph_crct_1_pt164n44.csv
# Error: ._nacorrected_asgngrph_crct_3_pt178.csv
# Done: input_files.txt
# Done: LoopedNormalization.ipynb
# Error: nacorrected_asgngrph_crct_10_4045402106.csv
# Error: nacorrected_asgngrph_crct_11_Pt109N28.csv
# Error: nacorrected_asgngrph_crct_12_Pt111N30.csv
# Error: nacorrected_asgngrph_crct_13_4045400686.csv
# Error: nacorrected_asgngrph_crct_13_PBS_PBS-2.csv
# Error: nacorrected_asgngrph_crct_14_pt135n37.csv
# Error: nacorrected_asgngrph_crct_15_4045401472.csv
# Error: nacorrected_asgngrph_crct_16_PC103clinic.csv
# Error: nacorrected_asgngrph_crct_17_PC6Bpreop.csv
# Error: nacorrected_asgngrph_crct_18_P28N5.csv
# Error: nacorrected_asgngrph_crct_19_4050.csv
# Error: nacorrected_asgngrph_crct_1_pt164n44.csv
# Error: nacorrected_asgngrph_crct_20_PC102clinic.csv
# Error: nacorrected_asgngrph_crct_21_PBS_PBS-3.csv
# Error: nacorrected_asgngrph_crct_21_PC93clinic.csv
# Error: nacorrected_asgngrph_crct_22_PC100clinic.csv
# Error: nacorrected_asgngrph_crct_23_3201.csv
# Error: nacorrected_asgngrph_crct_24_4045400934.csv
# Error: nacorrected_asgngrph_crct_25_4045400700.csv
# Error: nacorrected_asgngrph_crct_2_4045401399.csv
# Error: nacorrected_asgngrph_crct_3_pt178.csv
# Error: nacorrected_asgngrph_crct_4_PC6preop.csv
# Error: nacorrected_asgngrph_crct_5_4055.csv
# Error: nacorrected_asgngrph_crct_5_PBS_PBS-1.csv
# Error: nacorrected_asgngrph_crct_6_PC51preop.csv
# Error: nacorrected_asgngrph_crct_7_PC48clinic.csv
# Error: nacorrected_asgngrph_crct_8_PC32clinic.csv
# Error: nacorrected_asgngrph_crct_9_3439.csv
# Done: Normalization_EY.exe
# Done: Normalization_EY.ipynb
# Using reference m/z of 753.613371
# New Column Name is test2
# Done: .ipynb_checkpoints
# Error: ._nacorrected_asgngrph_crct_1_pt164n44.csv
# Error: ._nacorrected_asgngrph_crct_3_pt178.csv
# Done: input_files.txt
# Done: LoopedNormalization.ipynb
# Done: nacorrected_asgngrph_crct_10_4045402106.csv
# Done: nacorrected_asgngrph_crct_11_Pt109N28.csv
# Done: nacorrected_asgngrph_crct_12_Pt111N30.csv
# Done: nacorrected_asgngrph_crct_13_4045400686.csv
# Done: nacorrected_asgngrph_crct_13_PBS_PBS-2.csv
# Done: nacorrected_asgngrph_crct_14_pt135n37.csv
# Done: nacorrected_asgngrph_crct_15_4045401472.csv
# Error: nacorrected_asgngrph_crct_16_PC103clinic.csv
# Done: nacorrected_asgngrph_crct_17_PC6Bpreop.csv
# Done: nacorrected_asgngrph_crct_18_P28N5.csv
# Done: nacorrected_asgngrph_crct_19_4050.csv
# Done: nacorrected_asgngrph_crct_1_pt164n44.csv
# Done: nacorrected_asgngrph_crct_20_PC102clinic.csv
# Done: nacorrected_asgngrph_crct_21_PBS_PBS-3.csv
# Done: nacorrected_asgngrph_crct_21_PC93clinic.csv
# Done: nacorrected_asgngrph_crct_22_PC100clinic.csv
# Done: nacorrected_asgngrph_crct_23_3201.csv
# Done: nacorrected_asgngrph_crct_24_4045400934.csv
# Done: nacorrected_asgngrph_crct_25_4045400700.csv
# Done: nacorrected_asgngrph_crct_2_4045401399.csv
# Done: nacorrected_asgngrph_crct_3_pt178.csv
# Done: nacorrected_asgngrph_crct_4_PC6preop.csv
# Done: nacorrected_asgngrph_crct_5_4055.csv
# Done: nacorrected_asgngrph_crct_5_PBS_PBS-1.csv
# Done: nacorrected_asgngrph_crct_6_PC51preop.csv
# Done: nacorrected_asgngrph_crct_7_PC48clinic.csv
# Done: nacorrected_asgngrph_crct_8_PC32clinic.csv
# Done: nacorrected_asgngrph_crct_9_3439.csv
# Done: Normalization_EY.exe
# Done: Normalization_EY.ipynb
